# %% [markdown]
# df = Data Frame

# %%
import pandas as pd

excel_file_path = '/content/sample_data/MSCI151 Data.xlsx'
df = pd.read_excel(excel_file_path)

print("Heading of the data:")
display(df.head())
# Out:
# Heading of the data:
#    id  Profitability   debt     RnD  Firm Age  Firm Size  CEO Experience  \
# 0   1           0.02  23.76   53.09      3.43      21.22               2
# 1   2           3.99  41.85   45.30      3.22      21.83               4
# 2   3          41.98  61.84   51.16      3.18      20.54               3
# 3   4           8.48  25.61  115.49      3.26      20.59               3
# 4   5          -1.94  74.24   13.57      3.26      18.73               3
#
#    foreign sales  CEO education  CEO Gender
# 0           9.16              2           0
# 1          41.42              1           0
# 2           5.88              3           1
# 3          11.08              2           0
# 4          24.61              1           0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Prepare the data
Y = df['Profitability']
X = df[['debt', 'RnD', 'Firm Age', 'Firm Size', 'CEO Experience', 'foreign sales', 'CEO education', 'CEO Gender']]

print("Features (X) heading:")
display(X.head())

print("\nTarget (Y) heading:")
display(Y.head())

# Split the data into training and testing sets (80/20 split)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("\nTraining data shapes:")
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)

print("\nTesting data shapes:")
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)

# Train the Random Forest model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, Y_train)

print("\nRandom Forest model trained successfully.")
# Out:
# Features (X) heading:
#     debt     RnD  Firm Age  Firm Size  CEO Experience  foreign sales  \
# 0  23.76   53.09      3.43      21.22               2           9.16
# 1  41.85   45.30      3.22      21.83               4          41.42
# 2  61.84   51.16      3.18      20.54               3           5.88
# 3  25.61  115.49      3.26      20.59               3          11.08
# 4  74.24   13.57      3.26      18.73               3          24.61
#
#    CEO education  CEO Gender
# 0              2           0
# 1              1           0
# 2              3           1
# 3              2           0
# 4              1           0
# Target (Y) heading:
# 0     0.02
# 1     3.99
# 2    41.98
# 3     8.48
# 4    -1.94
# Name: Profitability, dtype: float64
# Training data shapes:
# X_train shape: (97, 8)
# Y_train shape: (97,)
#
# Testing data shapes:
# X_test shape: (25, 8)
# Y_test shape: (25,)
#
# Random Forest model trained successfully.

# %%
import pandas as pd

excel_file_path_new = '/content/sample_data/MSCI151 Data_New.xlsx'
df_new = pd.read_excel(excel_file_path_new)

print("Heading of the new data:")
display(df_new.head())
# Out:
# Heading of the new data:
#    id  Profitability   debt     RnD  Firm Age  Firm Size  CEO Experience  \
# 0   1           0.02  23.76   53.09      3.43      21.22               2
# 1   2           3.99  41.85   45.30      3.22      21.83               4
# 2   3          41.98  61.84   51.16      3.18      20.54               3
# 3   4           8.48  25.61  115.49      3.26      20.59               3
# 4   5          -1.94  74.24   13.57      3.26      18.73               3
#
#    foreign sales  CEO education  CEO Gender  Marketing  Product_sentiment  \
# 0           9.16              2           0   0.937385           0.328754
# 1          41.42              1           0   0.144503           0.694774
# 2           5.88              3           1   0.419529           0.550247
# 3          11.08              2           0   0.467164           0.972665
# 4          24.61              1           0   0.902376           0.219224
#
#    poloticians  PoB
# 0     0.801774    1
# 1     0.155627    0
# 2     0.597797    0
# 3     0.704388    1
# 4     0.890392    1

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.0.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.27.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

# Prepare the data
Y = df_new['Profitability']
X = df_new[['debt', 'CEO Gender']] # Updated features

print("Features (X) heading:")
display(X.head())

print("\nTarget (Y) heading:")
display(Y.head())

# Split the data into training and testing sets (80/20 split)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("\nTraining data shapes:")
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)

print("\nTesting data shapes:")
print("X_test shape:", X_test.shape)
print("Y_test shape:", Y_test.shape)

# Train the Decision Tree model
model = DecisionTreeRegressor(random_state=42)
model.fit(X_train, Y_train)

print("\nDecision Tree model trained successfully with updated features.")
# Out:
# Features (X) heading:
#     debt  CEO Gender
# 0  23.76           0
# 1  41.85           0
# 2  61.84           1
# 3  25.61           0
# 4  74.24           0
# Target (Y) heading:
# 0     0.02
# 1     3.99
# 2    41.98
# 3     8.48
# 4    -1.94
# Name: Profitability, dtype: float64
# Training data shapes:
# X_train shape: (97, 2)
# Y_train shape: (97,)
#
# Testing data shapes:
# X_test shape: (25, 2)
# Y_test shape: (25,)
#
# Decision Tree model trained successfully with updated features.

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Make predictions on the test set
Y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(Y_test, Y_pred)
print(f"Mean Squared Error (MSE): {mse:.4f}")

# Calculate R-squared score
r2 = r2_score(Y_test, Y_pred)
print(f"R-squared (R2) score: {r2:.4f}")
# Out:
# Mean Squared Error (MSE): 367.7851
# R-squared (R2) score: -6.9873

# %%
# Get feature importances from the trained model
feature_importances = model.feature_importances_

# Get the names of the features
feature_names = X.columns

# Create a pandas Series for better visualization
feature_importance_series = pd.Series(feature_importances, index=feature_names)

# Sort the features by importance in descending order
sorted_feature_importances = feature_importance_series.sort_values(ascending=False)

print("Feature Importance Scores:")
display(sorted_feature_importances)
# Out:
# Feature Importance Scores:
# debt          0.834438
# CEO Gender    0.165562
# dtype: float64

# %%
from sklearn.linear_model import Lasso
import pandas as pd

# Initialize and train the LASSO model
# We use a relatively small alpha (regularization strength) here;
# you might want to experiment with different alpha values.
lasso = Lasso(alpha=0.1, random_state=42)
lasso.fit(X, Y)

# Get the coefficients
lasso_coefficients = lasso.coef_

# Get the names of the features
feature_names = X.columns

# Create a pandas Series for better visualization
lasso_feature_importance = pd.Series(lasso_coefficients, index=feature_names)

# Sort the features by the absolute value of their coefficients in descending order
sorted_lasso_importance = lasso_feature_importance.abs().sort_values(ascending=False)

print("LASSO Coefficients (sorted by absolute value):")
display(lasso_feature_importance[sorted_lasso_importance.index])
# Out:
# LASSO Coefficients (sorted by absolute value):
# CEO Gender    11.728600
# debt          -0.184502
# dtype: float64

# %%
import statsmodels.api as sm

# Add a constant (intercept) to the features
X_with_intercept = sm.add_constant(X)

# Initialize and train the OLS model
# We use the 'hc1' option for robust standard errors (White's standard errors)
ols_model = sm.OLS(Y, X_with_intercept)
results = ols_model.fit(cov_type='hc1')

# Print the summary of the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Profitability   R-squared:                       0.226
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     15.74
# Date:                Wed, 08 Oct 2025   Prob (F-statistic):           8.60e-07
# Time:                        05:43:51   Log-Likelihood:                -469.88
# No. Observations:                 122   AIC:                             945.8
# Df Residuals:                     119   BIC:                             954.2
# Df Model:                           2
# Covariance Type:                  hc1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.8185      3.188      2.453      0.014       1.571      14.066
# debt          -0.1815      0.088     -2.070      0.038      -0.353      -0.010
# CEO Gender    12.4316      2.473      5.026      0.000       7.584      17.279
# ==============================================================================
# Omnibus:                      122.526   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2608.104
# Skew:                          -3.299   Prob(JB):                         0.00
# Kurtosis:                      24.669   Cond. No.                         151.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %%
from sklearn.decomposition import PCA
import pandas as pd

# Define the features (X)
X = df_new[['debt', 'RnD', 'Firm Age', 'Firm Size', 'CEO Experience', 'foreign sales', 'CEO education', 'CEO Gender', 'Marketing', 'Product_sentiment', 'PoB']]

# Initialize and fit PCA
# You can specify the number of components, or leave it as None to keep all components
pca = PCA()
pca.fit(X)

# Get the loading factors (components)
# The loading factors are the eigenvectors of the covariance matrix
loading_factors = pca.components_

# Create a DataFrame for better visualization of loading factors
loading_factors_df = pd.DataFrame(loading_factors, columns=X.columns, index=[f'PC{i+1}' for i in range(loading_factors.shape[0])])

print("Principal Component Analysis Loading Factors:")
print(loading_factors_df)
# Out:
# Principal Component Analysis Loading Factors:
#           debt       RnD  Firm Age  Firm Size  CEO Experience  foreign sales  \
# PC1  -0.002215  0.993123  0.000434   0.000475        0.001620      -0.117011
# PC2  -0.007649  0.116990 -0.002204  -0.001811        0.002525       0.993094
# PC3   0.999932  0.003096 -0.001243  -0.004380       -0.003073       0.007344
# PC4   0.004791 -0.000426  0.056706   0.993977        0.066819       0.001894
# PC5  -0.001762  0.000207 -0.107111   0.005545       -0.653587       0.002237
# PC6   0.001124 -0.002335  0.558187  -0.091227        0.517016       0.000700
# PC7   0.004516  0.000394 -0.119559  -0.053825        0.370410      -0.001373
# PC8  -0.000241  0.001341  0.767124  -0.006663       -0.368171       0.002443
# PC9   0.004417  0.000838  0.130552  -0.000844       -0.152659      -0.000794
# PC10  0.000530 -0.001061 -0.166315   0.016837        0.062219      -0.000852
# PC11  0.002316 -0.000541  0.162034  -0.020191       -0.033256      -0.000529
#
#       CEO education  CEO Gender  Marketing  Product_sentiment       PoB
# PC1        0.001569    0.000619   0.000673           0.000973 -0.001514
# PC2       -0.001700    0.001034  -0.000185           0.000525  0.000255
# PC3        0.001895   -0.004721   0.001666          -0.000325 -0.003726
# PC4        0.048345    0.030079  -0.023214           0.004659  0.022351
# PC5        0.687053    0.288406  -0.031248           0.022469  0.067906
# PC6        0.492251    0.285928   0.053271          -0.055904 -0.287689
# PC7        0.186974    0.131052  -0.125756          -0.020238  0.881603
# PC8       -0.145063   -0.263688   0.233597           0.001051  0.361629
# PC9       -0.447174    0.775488  -0.124126          -0.376367  0.034985
# PC10      -0.072959    0.305778   0.860562           0.354904  0.053248
# PC11      -0.148362    0.229239  -0.411445           0.853421 -0.007009
